# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
import time


def a(kilo, boy):
    vki = kilo // boy**2
    return vki

def b(vki):



    if bki < 18.5:
        return "Zayıf"
    elif 18.5 <= bki <= 24.9:
        return "Normal kilolu"
    elif 25 <= bki <= 29.9:
        return "Fazla kilolu"
    elif 30 <= bki <= 39.9:
        return "Obez"
    else:
        return "İleri derecede obez (morbid obez)"
    


def c(isim, yas, kilo, boy, vki, deger):
    kayıt = time.ctime(time.time())
    t1 = f"kullanıcı adı {isim}\n"



    t2 = f"kullanıcının kilo , boy ve yas bilgisi {kilo} ,{boy},{yas}\n"

    t3 = f"kullanıcının vücut kitle indexi {vki}\n"

    t4 = f"kullanıcın değer aralığı {deger}\n"
    t5 = f"kullanıcın kayıt tarihi {kayıt}\n"


    son = t1 +t2 +t3 + t4 +t5
    return son

def main():
    giris = int(input("kaç kullanıcı verisi girilecek"))

    for i in range(giris):
        print(f"kullanıcı kaydı {i+1}")

        isim = input("isim soyisim:  ")
        yas = int(input("yaşınız:  "))

        kilo = float(input("kilonuz:  "))

        boy = int(input("boyunuz:  "))

        vki = a(kilo, boy)

        deger = b(vki)

        out = c(isim, yas, kilo, boy, vki, deger)


        with open("saglık.txt", "a") as f:
            f.write(out)
            f.write("/n")


main()

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
import datetime

class Smoothie:
    def __init__(self, ad, fiyat, malzemeler):
        self.ad = ad
        self.fiyat = fiyat
        self.malzemeler = malzemeler

class YetBarOtomat:
    def __init__(self):
        self.smoothies = [
            Smoothie("Mango Smoothie", 15.0, ["mango", "yoğurt", "bal"]),
            Smoothie("Çilek Smoothie", 12.5, ["çilek", "süt", "bal"]),
            Smoothie("Yeşil Smoothie", 18.0, ["ıspanak", "avokado", "portakal"]),
            Smoothie("Protein Smoothie", 20.0, ["yulaf ezmesi", "çilek", "süt"])
        ]
        self.satislar = []

    def menu_goruntule(self):
        print("YetBar Smoothie Menüsü")
        print("------------------------")
        for smoothie in self.smoothies:
            print(smoothie.ad + " - " + ", ".join(smoothie.malzemeler) + " - " + str(smoothie.fiyat) + " TL")
        print("------------------------")

    def smoothie_satin_al(self, smoothie_index):
        smoothie = self.smoothies[smoothie_index]
        tarih = datetime.datetime.now()
        fiyat = smoothie.fiyat
        self.satislar.append((tarih, fiyat))
        print(smoothie.ad + " satın alındı. " + str(fiyat) + " TL ödeme yapıldı.")

    def satislari_goruntule(self):
        if len(self.satislar) == 0:
            print("Henüz satış yapılmadı.")
        else:
            print("Satışlar")
            print("------------------------")
            for satis in self.satislar:
                print(satis[0].strftime("%d/%m/%Y %H:%M:%S") + " - " + str(satis[1]) + " TL")
            

otomat = YetBarOtomat()

while True:
    print("1. Menüyü Görüntüle")
    print("2. Smoothie Satın Al")
    print("3. Satışları Görüntüle")
    print("4. Çıkış")
    secim = input("Seçiminiz: ")

    if secim == "1":
        otomat.menu_goruntule()
    elif secim == "2":
        otomat.menu_goruntule()
        smoothie_index = int(input("Hangi smoothie'yi satın almak istersiniz? (1-" + str(len(otomat.smoothies)) + "): ")) - 1
        if smoothie_index >= 0 and smoothie_index < len(otomat.smoothies):
            otomat.smoothie_s
